# %% [markdown]
# DataScienceEcosystem.ipynb

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y entornos de ciencia de datos.

# %% [markdown]
# **Objetivos**
# - Conocer leguajes de programación en Ciencia de Datos (Phyton, R,...)
# - Para qué sirve Anaconda
# - Cómo usar repositorios (GitHub)

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los científicos de datos son:
# 1. Phyton
# 2. R
# 3. Julia

# %% [markdown]
# |Herramientas de Ciencia de Datos|
# |------|
# |Phyton|
# |R|
# |Jupyter Notebook|

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python

# %%
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros
(3*4)+5
# Out:
# 17

# %%
# Esto convertirá 200 minutos a horas dividiendo por 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# María Jesús González Muñoz
